# %%
import pandas as pd
import seaborn as sns

# %%
data = pd.read_csv(r"C:\Users\PRITAM\Downloads\weblog.csv")

# %%
data.head()
# Out:
#            IP                   Time  \
# 0  10.128.2.1  [29/Nov/2017:06:58:55
# 1  10.128.2.1  [29/Nov/2017:06:59:02
# 2  10.128.2.1  [29/Nov/2017:06:59:03
# 3  10.131.2.1  [29/Nov/2017:06:59:04
# 4  10.130.2.1  [29/Nov/2017:06:59:06
#
#                                              URL Staus
# 0                        GET /login.php HTTP/1.1   200
# 1                     POST /process.php HTTP/1.1   302
# 2                         GET /home.php HTTP/1.1   200
# 3          GET /js/vendor/moment.min.js HTTP/1.1   200
# 4  GET /bootstrap-3.3.7/js/bootstrap.js HTTP/1.1   200

# %%
data.sample(10)
# Out:
#                IP                   Time  \
# 9449   10.130.2.1  [18/Jan/2018:12:47:52
# 230    10.131.2.1  [29/Nov/2017:16:21:44
# 6884   10.129.2.1  [19/Nov/2017:20:59:51
# 2164   10.129.2.1  [30/Nov/2017:15:52:10
# 2600   10.129.2.1  [30/Nov/2017:16:25:22
# 10576  10.131.0.1  [29/Jan/2018:20:26:25
# 2139   10.129.2.1  [30/Nov/2017:15:50:47
# 15979  10.128.2.1  [02/Mar/2018:15:45:42
# 9905   10.131.0.1  [29/Jan/2018:20:20:44
# 10476  10.131.0.1  [29/Jan/2018:20:24:39
#
#                                                      URL Staus
# 9449       GET /bootstrap-3.3.7/js/bootstrap.js HTTP/1.1   200
# 230                  GET /css/bootstrap.min.css HTTP/1.1   200
# 6884                 GET /css/bootstrap.min.css HTTP/1.1   200
# 2164                             GET /login.php HTTP/1.1   200
# 2600        GET /js/vendor/jquery-1.12.0.min.js HTTP/1.1   200
# 10576                             GET /home.php HTTP/1.1   302
# 2139   GET /contestproblem.php?name=RUET%20OJ%20Serve...   200
# 15979  GET /fonts/fontawesome-webfont.woff2?v=4.6.3 H...   200
# 9905                              GET /home.php HTTP/1.1   302
# 10476                             GET /home.php HTTP/1.1   302

# %%
df=data.Time.str.split(':',expand=True)

df
# Out:
#                   0   1   2   3
# 0      [29/Nov/2017  06  58  55
# 1      [29/Nov/2017  06  59  02
# 2      [29/Nov/2017  06  59  03
# 3      [29/Nov/2017  06  59  04
# 4      [29/Nov/2017  06  59  06
# ...             ...  ..  ..  ..
# 16002  [02/Mar/2018  15  47  12
# 16003  [02/Mar/2018  15  47  23
# 16004  [02/Mar/2018  15  47  32
# 16005  [02/Mar/2018  15  47  35
# 16006  [02/Mar/2018  15  47  46
#
# [16007 rows x 4 columns]

# %%
data
# Out:
#                IP                   Time  \
# 0      10.128.2.1  [29/Nov/2017:06:58:55
# 1      10.128.2.1  [29/Nov/2017:06:59:02
# 2      10.128.2.1  [29/Nov/2017:06:59:03
# 3      10.131.2.1  [29/Nov/2017:06:59:04
# 4      10.130.2.1  [29/Nov/2017:06:59:06
# ...           ...                    ...
# 16002  10.130.2.1  [02/Mar/2018:15:47:12
# 16003  10.130.2.1  [02/Mar/2018:15:47:23
# 16004  10.130.2.1  [02/Mar/2018:15:47:32
# 16005  10.130.2.1  [02/Mar/2018:15:47:35
# 16006  10.130.2.1  [02/Mar/2018:15:47:46
#
#                                                  URL Staus
# 0                            GET /login.php HTTP/1.1   200
# 1                         POST /process.php HTTP/1.1   302
# 2                             GET /home.php HTTP/1.1   200
# 3              GET /js/vendor/moment.min.js HTTP/1.1   200
# 4      GET /bootstrap-3.3.7/js/bootstrap.js HTTP/1.1   200
# ...                                              ...   ...
# 16002     GET /showcode.php?id=309&nm=ham05 HTTP/1.1   200
# 16003                GET /allsubmission.php HTTP/1.1   200
# 16004     GET /showcode.php?id=309&nm=ham05 HTTP/1.1   200
# 16005                GET /allsubmission.php HTTP/1.1   200
# 16006                         GET /home.php HTTP/1.1   200
#
# [16007 rows x 4 columns]

# %%
dt=["Date","Hour","Minute","Second"]

# %%
df.columns=dt

# %%
df.head()
# Out:
#            Date Hour Minute Second
# 0  [29/Nov/2017   06     58     55
# 1  [29/Nov/2017   06     59     02
# 2  [29/Nov/2017   06     59     03
# 3  [29/Nov/2017   06     59     04
# 4  [29/Nov/2017   06     59     06

# %%
df1=df.Date.str.split('[',expand=True)

# %%
df1.head()
# Out:
#   0            1
# 0    29/Nov/2017
# 1    29/Nov/2017
# 2    29/Nov/2017
# 3    29/Nov/2017
# 4    29/Nov/2017

# %%
df1.sample(10)
# Out:
#       0            1
# 7042     21/Nov/2017
# 11022    29/Jan/2018
# 14936    21/Feb/2018
# 9023     18/Dec/2017
# 512      29/Nov/2017
# 12666    29/Jan/2018
# 120      29/Nov/2017
# 13862    29/Jan/2018
# 4281     03/Dec/2017
# 12300    29/Jan/2018

# %%
temp=pd.DatetimeIndex(df1[1])

# %%
df1["Day"]=temp.day

# %%
df1["Day"].head()
# Out:
# 0    29.0
# 1    29.0
# 2    29.0
# 3    29.0
# 4    29.0
# Name: Day, dtype: float64

# %%
df1.head()
# Out:
#   0            1   Day
# 0    29/Nov/2017  29.0
# 1    29/Nov/2017  29.0
# 2    29/Nov/2017  29.0
# 3    29/Nov/2017  29.0
# 4    29/Nov/2017  29.0

# %%
df1.columns
# Out:
# Index([0, 1, 'Day'], dtype='object')

# %%
df_cols=["Index","Date","Day"]

# %%
df1.columns=df_cols

# %%
df1
# Out:
#       Index         Date   Day
# 0            29/Nov/2017  29.0
# 1            29/Nov/2017  29.0
# 2            29/Nov/2017  29.0
# 3            29/Nov/2017  29.0
# 4            29/Nov/2017  29.0
# ...     ...          ...   ...
# 16002        02/Mar/2018   2.0
# 16003        02/Mar/2018   2.0
# 16004        02/Mar/2018   2.0
# 16005        02/Mar/2018   2.0
# 16006        02/Mar/2018   2.0
#
# [16007 rows x 3 columns]

# %%
df.head()
# Out:
#            Date Hour Minute Second
# 0  [29/Nov/2017   06     58     55
# 1  [29/Nov/2017   06     59     02
# 2  [29/Nov/2017   06     59     03
# 3  [29/Nov/2017   06     59     04
# 4  [29/Nov/2017   06     59     06

# %%
df_cols=["Date","Hour","Minute","Second"]

# %%
df.columns=df_cols

# %%
df.head()
# Out:
#            Date Hour Minute Second
# 0  [29/Nov/2017   06     58     55
# 1  [29/Nov/2017   06     59     02
# 2  [29/Nov/2017   06     59     03
# 3  [29/Nov/2017   06     59     04
# 4  [29/Nov/2017   06     59     06

# %%
df6=df.Hour
df7=df.Minute
df8=df.Second

# %%
df6.head()
# Out:
# 0    06
# 1    06
# 2    06
# 3    06
# 4    06
# Name: Hour, dtype: object

# %%
df1.head()
# Out:
#   Index         Date   Day
# 0        29/Nov/2017  29.0
# 1        29/Nov/2017  29.0
# 2        29/Nov/2017  29.0
# 3        29/Nov/2017  29.0
# 4        29/Nov/2017  29.0

# %%
df4=df1.Day

# %%
df5=df1.Date

# %%
df5
# Out:
# 0        29/Nov/2017
# 1        29/Nov/2017
# 2        29/Nov/2017
# 3        29/Nov/2017
# 4        29/Nov/2017
#             ...
# 16002    02/Mar/2018
# 16003    02/Mar/2018
# 16004    02/Mar/2018
# 16005    02/Mar/2018
# 16006    02/Mar/2018
# Name: Date, Length: 16007, dtype: object

# %%
df4
# Out:
# 0        29.0
# 1        29.0
# 2        29.0
# 3        29.0
# 4        29.0
#          ...
# 16002     2.0
# 16003     2.0
# 16004     2.0
# 16005     2.0
# 16006     2.0
# Name: Day, Length: 16007, dtype: float64

# %%
data['Day'] = df4
data.head()
# Out:
#            IP                   Time  \
# 0  10.128.2.1  [29/Nov/2017:06:58:55
# 1  10.128.2.1  [29/Nov/2017:06:59:02
# 2  10.128.2.1  [29/Nov/2017:06:59:03
# 3  10.131.2.1  [29/Nov/2017:06:59:04
# 4  10.130.2.1  [29/Nov/2017:06:59:06
#
#                                              URL Staus   Day
# 0                        GET /login.php HTTP/1.1   200  29.0
# 1                     POST /process.php HTTP/1.1   302  29.0
# 2                         GET /home.php HTTP/1.1   200  29.0
# 3          GET /js/vendor/moment.min.js HTTP/1.1   200  29.0
# 4  GET /bootstrap-3.3.7/js/bootstrap.js HTTP/1.1   200  29.0

# %%
data['Date'] = df5
data.head()
# Out:
#            IP                   Time  \
# 0  10.128.2.1  [29/Nov/2017:06:58:55
# 1  10.128.2.1  [29/Nov/2017:06:59:02
# 2  10.128.2.1  [29/Nov/2017:06:59:03
# 3  10.131.2.1  [29/Nov/2017:06:59:04
# 4  10.130.2.1  [29/Nov/2017:06:59:06
#
#                                              URL Staus   Day         Date
# 0                        GET /login.php HTTP/1.1   200  29.0  29/Nov/2017
# 1                     POST /process.php HTTP/1.1   302  29.0  29/Nov/2017
# 2                         GET /home.php HTTP/1.1   200  29.0  29/Nov/2017
# 3          GET /js/vendor/moment.min.js HTTP/1.1   200  29.0  29/Nov/2017
# 4  GET /bootstrap-3.3.7/js/bootstrap.js HTTP/1.1   200  29.0  29/Nov/2017

# %%
data['Hour'] = df6

data.head()
# Out:
#            IP                   Time  \
# 0  10.128.2.1  [29/Nov/2017:06:58:55
# 1  10.128.2.1  [29/Nov/2017:06:59:02
# 2  10.128.2.1  [29/Nov/2017:06:59:03
# 3  10.131.2.1  [29/Nov/2017:06:59:04
# 4  10.130.2.1  [29/Nov/2017:06:59:06
#
#                                              URL Staus   Day         Date Hour
# 0                        GET /login.php HTTP/1.1   200  29.0  29/Nov/2017   06
# 1                     POST /process.php HTTP/1.1   302  29.0  29/Nov/2017   06
# 2                         GET /home.php HTTP/1.1   200  29.0  29/Nov/2017   06
# 3          GET /js/vendor/moment.min.js HTTP/1.1   200  29.0  29/Nov/2017   06
# 4  GET /bootstrap-3.3.7/js/bootstrap.js HTTP/1.1   200  29.0  29/Nov/2017   06

# %%
data.sample(5)
# Out:
#                IP                   Time                         URL Staus  \
# 7981   10.131.2.1  [26/Nov/2017:19:52:45   GET /process.php HTTP/1.0   302
# 8807   10.128.2.1  [17/Dec/2017:18:43:07  POST /process.php HTTP/1.1   302
# 6417   10.129.2.1  [17/Nov/2017:05:02:13              GET / HTTP/1.1   302
# 2289   10.129.2.1  [30/Nov/2017:16:00:45     GET /login.php HTTP/1.1   200
# 13137  10.130.2.1  [29/Jan/2018:20:47:12      GET /home.php HTTP/1.1   302
#
#         Day         Date Hour
# 7981   26.0  26/Nov/2017   19
# 8807   17.0  17/Dec/2017   18
# 6417   17.0  17/Nov/2017   05
# 2289   30.0  30/Nov/2017   16
# 13137  29.0  29/Jan/2018   20

# %%
data.isnull().sum()
# Out:
# IP         0
# Time       0
# URL        0
# Staus      0
# Day      218
# Date     218
# Hour     212
# dtype: int64

# %%
df_1=data.dropna(how='any')

# %%
df_1.isnull().sum()
# Out:
# IP       0
# Time     0
# URL      0
# Staus    0
# Day      0
# Date     0
# Hour     0
# dtype: int64

# %%
df_1.sample(10)
# Out:
#                IP                   Time  \
# 12786  10.131.0.1  [29/Jan/2018:20:44:27
# 12527  10.131.0.1  [29/Jan/2018:20:41:39
# 13125  10.128.2.1  [29/Jan/2018:20:47:07
# 14190  10.128.2.1  [29/Jan/2018:20:54:28
# 7350   10.131.0.1  [23/Nov/2017:18:37:30
# 428    10.131.2.1  [29/Nov/2017:17:54:43
# 698    10.131.0.1  [30/Nov/2017:09:35:56
# 7568   10.128.2.1  [24/Nov/2017:14:58:51
# 13347  10.131.0.1  [29/Jan/2018:20:47:45
# 8969   10.130.2.1  [18/Dec/2017:19:01:59
#
#                                                   URL Staus   Day  \
# 12786  GET /js/vendor/modernizr-2.8.3.min.js HTTP/1.1   200  29.0
# 12527                          GET /home.php HTTP/1.1   302  29.0
# 13125  GET /js/vendor/modernizr-2.8.3.min.js HTTP/1.1   200  29.0
# 14190                          GET /home.php HTTP/1.1   302  29.0
# 7350                       POST /process.php HTTP/1.1   302  23.0
# 428                            GET /home.php HTTP/1.1   302  29.0
# 698                           GET /login.php HTTP/1.1   200  30.0
# 7568   GET /js/vendor/modernizr-2.8.3.min.js HTTP/1.1   200  24.0
# 13347                          GET /home.php HTTP/1.1   302  29.0
# 8969                 GET /archive.php?page=1 HTTP/1.1   200  18.0
#
#               Date Hour
# 12786  29/Jan/2018   20
# 12527  29/Jan/2018   20
# 13125  29/Jan/2018   20
# 14190  29/Jan/2018   20
# 7350   23/Nov/2017   18
# 428    29/Nov/2017   17
# 698    30/Nov/2017   09
# 7568   24/Nov/2017   14
# 13347  29/Jan/2018   20
# 8969   18/Dec/2017   19

# %%
df_1.drop('Time',axis=1,inplace=True)
# Out:
# c:\users\pritam\appdata\local\programs\python\python37-32\lib\site-packages\pandas\core\frame.py:3997: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
df_1
# Out:
#                IP                                            URL Staus   Day  \
# 0      10.128.2.1                        GET /login.php HTTP/1.1   200  29.0
# 1      10.128.2.1                     POST /process.php HTTP/1.1   302  29.0
# 2      10.128.2.1                         GET /home.php HTTP/1.1   200  29.0
# 3      10.131.2.1          GET /js/vendor/moment.min.js HTTP/1.1   200  29.0
# 4      10.130.2.1  GET /bootstrap-3.3.7/js/bootstrap.js HTTP/1.1   200  29.0
# ...           ...                                            ...   ...   ...
# 16002  10.130.2.1     GET /showcode.php?id=309&nm=ham05 HTTP/1.1   200   2.0
# 16003  10.130.2.1                GET /allsubmission.php HTTP/1.1   200   2.0
# 16004  10.130.2.1     GET /showcode.php?id=309&nm=ham05 HTTP/1.1   200   2.0
# 16005  10.130.2.1                GET /allsubmission.php HTTP/1.1   200   2.0
# 16006  10.130.2.1                         GET /home.php HTTP/1.1   200   2.0
#
#               Date Hour
# 0      29/Nov/2017   06
# 1      29/Nov/2017   06
# 2      29/Nov/2017   06
# 3      29/Nov/2017   06
# 4      29/Nov/2017   06
# ...            ...  ...
# 16002  02/Mar/2018   15
# 16003  02/Mar/2018   15
# 16004  02/Mar/2018   15
# 16005  02/Mar/2018   15
# 16006  02/Mar/2018   15
#
# [15789 rows x 6 columns]

# %%
df_1.isnull().sum()
# Out:
# IP       0
# URL      0
# Staus    0
# Day      0
# Date     0
# Hour     0
# dtype: int64

# %%
df_1['Minute'] = df7

df_1.head()
# Out:
# c:\users\pritam\appdata\local\programs\python\python37-32\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#            IP                                            URL Staus   Day  \
# 0  10.128.2.1                        GET /login.php HTTP/1.1   200  29.0
# 1  10.128.2.1                     POST /process.php HTTP/1.1   302  29.0
# 2  10.128.2.1                         GET /home.php HTTP/1.1   200  29.0
# 3  10.131.2.1          GET /js/vendor/moment.min.js HTTP/1.1   200  29.0
# 4  10.130.2.1  GET /bootstrap-3.3.7/js/bootstrap.js HTTP/1.1   200  29.0
#
#           Date Hour Minute
# 0  29/Nov/2017   06     58
# 1  29/Nov/2017   06     59
# 2  29/Nov/2017   06     59
# 3  29/Nov/2017   06     59
# 4  29/Nov/2017   06     59

# %%
df_1['Second'] = df8

df_1.sample(10)
# Out:
# c:\users\pritam\appdata\local\programs\python\python37-32\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#                IP                                           URL Staus   Day  \
# 160    10.131.2.1                     GET /archive.php HTTP/1.1   200  29.0
# 229    10.131.2.1                   GET /css/style.css HTTP/1.1   200  29.0
# 15856  10.131.0.1                    GET /css/main.css HTTP/1.1   200   2.0
# 431    10.131.2.1                       GET /login.php HTTP/1.1   200  29.0
# 14898  10.130.2.1  GET /js/vendor/jquery-1.12.0.min.js HTTP/1.1   200  21.0
# 3808   10.128.2.1  GET /profile.php?user=samin_1610002 HTTP/1.1   200   1.0
# 5102   10.130.2.1                    GET /img/ruet.png HTTP/1.1   200  16.0
# 11653  10.128.2.1                       GET /login.php HTTP/1.1   200  29.0
# 2335   10.129.2.1                        GET /home.php HTTP/1.1   200  30.0
# 8882   10.131.0.1               GET /css/normalize.css HTTP/1.1   200  18.0
#
#               Date Hour Minute Second
# 160    29/Nov/2017   15     40     48
# 229    29/Nov/2017   16     21     43
# 15856  02/Mar/2018   04     30     47
# 431    29/Nov/2017   17     55     00
# 14898  21/Feb/2018   12     41     39
# 3808   01/Dec/2017   10     50     41
# 5102   16/Nov/2017   15     23     47
# 11653  29/Jan/2018   20     35     22
# 2335   30/Nov/2017   16     05     29
# 8882   18/Dec/2017   11     23     57

# %%
from matplotlib import pyplot as plt
import matplotlib.pyplot as plt
from matplotlib import rcParams
from matplotlib.cm import rainbow
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')
import seaborn as sns

# %%
df_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15789 entries, 0 to 16006
# Data columns (total 8 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   IP      15789 non-null  object
#  1   URL     15789 non-null  object
#  2   Staus   15789 non-null  object
#  3   Day     15789 non-null  float64
#  4   Date    15789 non-null  object
#  5   Hour    15789 non-null  object
#  6   Minute  15789 non-null  object
#  7   Second  15789 non-null  object
# dtypes: float64(1), object(7)
# memory usage: 678.4+ KB

# %%
df_1.describe
# Out:
# <bound method NDFrame.describe of                IP                                            URL Staus   Day  \
# 0      10.128.2.1                        GET /login.php HTTP/1.1   200  29.0
# 1      10.128.2.1                     POST /process.php HTTP/1.1   302  29.0
# 2      10.128.2.1                         GET /home.php HTTP/1.1   200  29.0
# 3      10.131.2.1          GET /js/vendor/moment.min.js HTTP/1.1   200  29.0
# 4      10.130.2.1  GET /bootstrap-3.3.7/js/bootstrap.js HTTP/1.1   200  29.0
# ...           ...                                            ...   ...   ...
# 16002  10.130.2.1     GET /showcode.php?id=309&nm=ham05 HTTP/1.1   200   2.0
# 16003  10.130.2.1                GET /allsubmission.php HTTP/1.1   200   2.0
# 16004  10.130.2.1     GET /showcode.php?id=309&nm=ham05 HTTP/1.1   200   2.0
# 16005  10.130.2.1                GET /allsubmission.php HTTP/1.1   200   2.0
# 16006  10.130.2.1                         GET /home.php HTTP/1.1   200   2.0
#
#               Date Hour Minute Second
# 0      29/Nov/2017   06     58     55
# 1      29/Nov/2017   06     59     02
# 2      29/Nov/2017   06     59     03
# 3      29/Nov/2017   06     59     04
# 4      29/Nov/2017   06     59     06
# ...            ...  ...    ...    ...
# 16002  02/Mar/2018   15     47     12
# 16003  02/Mar/2018   15     47     23
# 16004  02/Mar/2018   15     47     32
# 16005  02/Mar/2018   15     47     35
# 16006  02/Mar/2018   15     47     46
#
# [15789 rows x 8 columns]>

# %%
sns.pairplot(df_1.drop("URL",axis=1),hue="IP",size=5)
plt.show()

# %%
sns.FacetGrid(data=df_1,hue='IP',size=6).map(sns.kdeplot,'Day').add_legend()
plt.grid()
plt.show()

# %%
sns.boxplot(x="IP", y="Day", data=df_1)

# %%
sns.FacetGrid(data=df_1,hue='IP',size=6).map(sns.kdeplot,'Minute').add_legend()
plt.grid()
plt.show()

# %%
sns.FacetGrid(data=df_1,hue='IP',size=6).map(sns.kdeplot,'Hour').add_legend()
plt.grid()
plt.show()

# %%
sns.FacetGrid(data=df_1,hue='IP',size=6).map(sns.kdeplot,'Second').add_legend()
plt.grid()
plt.show()

# %%
sns.FacetGrid(data=df_1,hue='IP',size=6).map(sns.kdeplot,'Staus').add_legend()
plt.grid()
plt.show()

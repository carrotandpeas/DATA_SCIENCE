# %%
import pandas as pd
import seaborn as sns

# %%
data = pd.read_csv(r"C:\Users\PRITAM\Downloads\weblog.csv")

# %%
data.head()
# Out:
#            IP                   Time  \
# 0  10.128.2.1  [29/Nov/2017:06:58:55
# 1  10.128.2.1  [29/Nov/2017:06:59:02
# 2  10.128.2.1  [29/Nov/2017:06:59:03
# 3  10.131.2.1  [29/Nov/2017:06:59:04
# 4  10.130.2.1  [29/Nov/2017:06:59:06
#
#                                              URL Staus
# 0                        GET /login.php HTTP/1.1   200
# 1                     POST /process.php HTTP/1.1   302
# 2                         GET /home.php HTTP/1.1   200
# 3          GET /js/vendor/moment.min.js HTTP/1.1   200
# 4  GET /bootstrap-3.3.7/js/bootstrap.js HTTP/1.1   200

# %%
data.sample(10)
# Out:
#                IP                   Time  \
# 10664  10.131.0.1  [29/Jan/2018:20:26:38
# 7639   10.128.2.1  [25/Nov/2017:15:29:23
# 3212   10.131.2.1  [30/Nov/2017:17:45:57
# 12892  10.128.2.1  [29/Jan/2018:20:44:44
# 7973   10.131.2.1  [26/Nov/2017:19:52:21
# 11794  10.131.0.1  [29/Jan/2018:20:35:43
# 4877   10.129.2.1  [13/Nov/2017:13:02:24
# 2677   10.129.2.1  [30/Nov/2017:16:36:49
# 12582  10.130.2.1  [29/Jan/2018:20:41:51
# 10504  10.128.2.1  [29/Jan/2018:20:24:48
#
#                                                      URL Staus
# 10664                             GET /home.php HTTP/1.1   302
# 7639                              GET /home.php HTTP/1.1   200
# 3212   GET /contestproblem.php?name=RUET%20OJ%20Serve...   200
# 12892     GET /js/vendor/modernizr-2.8.3.min.js HTTP/1.1   200
# 7973                         GET /css/style.css HTTP/1.1   200
# 11794                             GET /home.php HTTP/1.1   302
# 4877      GET /js/vendor/modernizr-2.8.3.min.js HTTP/1.1   304
# ...

# %%
df=data.Time.str.split(':',expand=True)

df
# Out:
#                   0   1   2   3
# 0      [29/Nov/2017  06  58  55
# 1      [29/Nov/2017  06  59  02
# 2      [29/Nov/2017  06  59  03
# 3      [29/Nov/2017  06  59  04
# 4      [29/Nov/2017  06  59  06
# ...             ...  ..  ..  ..
# 16002  [02/Mar/2018  15  47  12
# 16003  [02/Mar/2018  15  47  23
# 16004  [02/Mar/2018  15  47  32
# 16005  [02/Mar/2018  15  47  35
# 16006  [02/Mar/2018  15  47  46
#
# [16007 rows x 4 columns]

# %%
data
# Out:
#                IP                   Time  \
# 0      10.128.2.1  [29/Nov/2017:06:58:55
# 1      10.128.2.1  [29/Nov/2017:06:59:02
# 2      10.128.2.1  [29/Nov/2017:06:59:03
# 3      10.131.2.1  [29/Nov/2017:06:59:04
# 4      10.130.2.1  [29/Nov/2017:06:59:06
# ...           ...                    ...
# 16002  10.130.2.1  [02/Mar/2018:15:47:12
# 16003  10.130.2.1  [02/Mar/2018:15:47:23
# 16004  10.130.2.1  [02/Mar/2018:15:47:32
# 16005  10.130.2.1  [02/Mar/2018:15:47:35
# 16006  10.130.2.1  [02/Mar/2018:15:47:46
#
#                                                  URL Staus
# 0                            GET /login.php HTTP/1.1   200
# 1                         POST /process.php HTTP/1.1   302
# 2                             GET /home.php HTTP/1.1   200
# 3              GET /js/vendor/moment.min.js HTTP/1.1   200
# 4      GET /bootstrap-3.3.7/js/bootstrap.js HTTP/1.1   200
# ...                                              ...   ...
# ...

# %%
dt=["Date","Hour","Minute","Second"]

# %%
df.columns=dt

# %%
df.head()
# Out:
#            Date Hour Minute Second
# 0  [29/Nov/2017   06     58     55
# 1  [29/Nov/2017   06     59     02
# 2  [29/Nov/2017   06     59     03
# 3  [29/Nov/2017   06     59     04
# 4  [29/Nov/2017   06     59     06

# %%
df1=df.Date.str.split('[',expand=True)

# %%
df1.head()
# Out:
#   0            1
# 0    29/Nov/2017
# 1    29/Nov/2017
# 2    29/Nov/2017
# 3    29/Nov/2017
# 4    29/Nov/2017

# %%
df1.sample(10)
# Out:
#       0            1
# 1436     30/Nov/2017
# 1384     30/Nov/2017
# 11466    29/Jan/2018
# 2186     30/Nov/2017
# 5635     10/Nov/2017
# 10743    29/Jan/2018
# 14942    21/Feb/2018
# 14525    29/Jan/2018
# 6928     19/Nov/2017
# 3249     30/Nov/2017

# %%
temp=pd.DatetimeIndex(df1[1])

# %%
df1["Day"]=temp.day

# %%
df1["Day"].head()
# Out:
# 0    29.0
# 1    29.0
# 2    29.0
# 3    29.0
# 4    29.0
# Name: Day, dtype: float64

# %%
df1.head()
# Out:
#   0            1   Day
# 0    29/Nov/2017  29.0
# 1    29/Nov/2017  29.0
# 2    29/Nov/2017  29.0
# 3    29/Nov/2017  29.0
# 4    29/Nov/2017  29.0

# %%
df1.columns
# Out:
# Index([0, 1, 'Day'], dtype='object')

# %%
df_cols=["Index","Date","Day"]

# %%
df1.columns=df_cols

# %%
df1
# Out:
#       Index         Date   Day
# 0            29/Nov/2017  29.0
# 1            29/Nov/2017  29.0
# 2            29/Nov/2017  29.0
# 3            29/Nov/2017  29.0
# 4            29/Nov/2017  29.0
# ...     ...          ...   ...
# 16002        02/Mar/2018   2.0
# 16003        02/Mar/2018   2.0
# 16004        02/Mar/2018   2.0
# 16005        02/Mar/2018   2.0
# 16006        02/Mar/2018   2.0
#
# [16007 rows x 3 columns]

# %%
df.head()
# Out:
#            Date Hour Minute Second
# 0  [29/Nov/2017   06     58     55
# 1  [29/Nov/2017   06     59     02
# 2  [29/Nov/2017   06     59     03
# 3  [29/Nov/2017   06     59     04
# 4  [29/Nov/2017   06     59     06

# %%
df_cols=["Date","Hour","Minute","Second"]

# %%
df.columns=df_cols

# %%
df.head()
# Out:
#            Date Hour Minute Second
# 0  [29/Nov/2017   06     58     55
# 1  [29/Nov/2017   06     59     02
# 2  [29/Nov/2017   06     59     03
# 3  [29/Nov/2017   06     59     04
# 4  [29/Nov/2017   06     59     06

# %%
df6=df.Hour
df7=df.Minute
df8=df.Second

# %%
df6.head()
# Out:
# 0    06
# 1    06
# 2    06
# 3    06
# 4    06
# Name: Hour, dtype: object

# %%
df1.head()
# Out:
#   Index         Date   Day
# 0        29/Nov/2017  29.0
# 1        29/Nov/2017  29.0
# 2        29/Nov/2017  29.0
# 3        29/Nov/2017  29.0
# 4        29/Nov/2017  29.0

# %%
df4=df1.Day

# %%
df5=df1.Date

# %%
df5
# Out:
# 0        29/Nov/2017
# 1        29/Nov/2017
# 2        29/Nov/2017
# 3        29/Nov/2017
# 4        29/Nov/2017
#             ...
# 16002    02/Mar/2018
# 16003    02/Mar/2018
# 16004    02/Mar/2018
# 16005    02/Mar/2018
# 16006    02/Mar/2018
# Name: Date, Length: 16007, dtype: object

# %%
df4
# Out:
# 0        29.0
# 1        29.0
# 2        29.0
# 3        29.0
# 4        29.0
#          ...
# 16002     2.0
# 16003     2.0
# 16004     2.0
# 16005     2.0
# 16006     2.0
# Name: Day, Length: 16007, dtype: float64

# %%
data['Day'] = df4
data.head()
# Out:
#            IP                   Time  \
# 0  10.128.2.1  [29/Nov/2017:06:58:55
# 1  10.128.2.1  [29/Nov/2017:06:59:02
# 2  10.128.2.1  [29/Nov/2017:06:59:03
# 3  10.131.2.1  [29/Nov/2017:06:59:04
# 4  10.130.2.1  [29/Nov/2017:06:59:06
#
#                                              URL Staus   Day
# 0                        GET /login.php HTTP/1.1   200  29.0
# 1                     POST /process.php HTTP/1.1   302  29.0
# 2                         GET /home.php HTTP/1.1   200  29.0
# 3          GET /js/vendor/moment.min.js HTTP/1.1   200  29.0
# 4  GET /bootstrap-3.3.7/js/bootstrap.js HTTP/1.1   200  29.0

# %%
data['Date'] = df5
data.head()
# Out:
#            IP                   Time  \
# 0  10.128.2.1  [29/Nov/2017:06:58:55
# 1  10.128.2.1  [29/Nov/2017:06:59:02
# 2  10.128.2.1  [29/Nov/2017:06:59:03
# 3  10.131.2.1  [29/Nov/2017:06:59:04
# 4  10.130.2.1  [29/Nov/2017:06:59:06
#
#                                              URL Staus   Day         Date
# 0                        GET /login.php HTTP/1.1   200  29.0  29/Nov/2017
# 1                     POST /process.php HTTP/1.1   302  29.0  29/Nov/2017
# 2                         GET /home.php HTTP/1.1   200  29.0  29/Nov/2017
# 3          GET /js/vendor/moment.min.js HTTP/1.1   200  29.0  29/Nov/2017
# 4  GET /bootstrap-3.3.7/js/bootstrap.js HTTP/1.1   200  29.0  29/Nov/2017

# %%
data['Hour'] = df6

data.head()
# Out:
#            IP                   Time  \
# 0  10.128.2.1  [29/Nov/2017:06:58:55
# 1  10.128.2.1  [29/Nov/2017:06:59:02
# 2  10.128.2.1  [29/Nov/2017:06:59:03
# 3  10.131.2.1  [29/Nov/2017:06:59:04
# 4  10.130.2.1  [29/Nov/2017:06:59:06
#
#                                              URL Staus   Day         Date Hour
# 0                        GET /login.php HTTP/1.1   200  29.0  29/Nov/2017   06
# 1                     POST /process.php HTTP/1.1   302  29.0  29/Nov/2017   06
# 2                         GET /home.php HTTP/1.1   200  29.0  29/Nov/2017   06
# 3          GET /js/vendor/moment.min.js HTTP/1.1   200  29.0  29/Nov/2017   06
# 4  GET /bootstrap-3.3.7/js/bootstrap.js HTTP/1.1   200  29.0  29/Nov/2017   06

# %%
data.sample(5)
# Out:
#                IP                   Time  \
# 15431      chmod:                 cannot
# 11936  10.128.2.1  [29/Jan/2018:20:36:36
# 10094  10.128.2.1  [29/Jan/2018:20:21:49
# 4688   10.128.2.1  [12/Nov/2017:05:59:16
# 1103   10.128.2.1  [30/Nov/2017:12:57:58
#
#                                                   URL Staus   Day  \
# 15431                                        'a.out':    No   NaN
# 11936                          GET /home.php HTTP/1.1   302  29.0
# 10094                          GET /home.php HTTP/1.1   302  29.0
# 4688                          GET /login.php HTTP/1.1   200  12.0
# 1103   GET /js/vendor/modernizr-2.8.3.min.js HTTP/1.1   200  30.0
#
#               Date  Hour
# 15431         None  None
# 11936  29/Jan/2018    20
# 10094  29/Jan/2018    20
# 4688   12/Nov/2017    05
# 1103   30/Nov/2017    12

# %%
data.isnull().sum()
# Out:
# IP         0
# Time       0
# URL        0
# Staus      0
# Day      218
# Date     218
# Hour     212
# dtype: int64

# %%
df_1=data.dropna(how='any')

# %%
df_1.isnull().sum()
# Out:
# IP       0
# Time     0
# URL      0
# Staus    0
# Day      0
# Date     0
# Hour     0
# dtype: int64

# %%
df_1.sample(10)
# Out:
#                IP                   Time  \
# 10498  10.131.0.1  [29/Jan/2018:20:24:46
# 262    10.129.2.1  [29/Nov/2017:16:22:41
# 10885  10.128.2.1  [29/Jan/2018:20:27:50
# 1923   10.128.2.1  [30/Nov/2017:15:30:34
# 804    10.129.2.1  [30/Nov/2017:12:07:52
# 150    10.129.2.1  [29/Nov/2017:15:12:58
# 10405  10.131.0.1  [29/Jan/2018:20:24:08
# 12704  10.130.2.1  [29/Jan/2018:20:42:40
# 15287  10.130.2.1  [23/Feb/2018:23:42:40
# 14941  10.130.2.1  [21/Feb/2018:15:26:29
#
#                                                      URL Staus   Day  \
# 10498                             GET /home.php HTTP/1.1   302  29.0
# 262         GET /js/vendor/jquery-1.12.0.min.js HTTP/1.1   200  29.0
# 10885                             GET /home.php HTTP/1.1   302  29.0
# 1923   GET /details.php?name=Matrix%20For%20My%20Vale...   200  30.0
# 804    GET /fonts/fontawesome-webfont.woff2?v=4.6.3 H...   200  30.0
# 150    GET /contestproblem.php?name=RUET%20OJ%20TLE%2...   200  29.0
# ...

# %%
df_1.drop('Time',axis=1,inplace=True)
# Out:
# c:\users\pritam\appdata\local\programs\python\python37\lib\site-packages\pandas\core\frame.py:3997: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
df_1
# Out:
#                IP                                            URL Staus   Day  \
# 0      10.128.2.1                        GET /login.php HTTP/1.1   200  29.0
# 1      10.128.2.1                     POST /process.php HTTP/1.1   302  29.0
# 2      10.128.2.1                         GET /home.php HTTP/1.1   200  29.0
# 3      10.131.2.1          GET /js/vendor/moment.min.js HTTP/1.1   200  29.0
# 4      10.130.2.1  GET /bootstrap-3.3.7/js/bootstrap.js HTTP/1.1   200  29.0
# ...           ...                                            ...   ...   ...
# 16002  10.130.2.1     GET /showcode.php?id=309&nm=ham05 HTTP/1.1   200   2.0
# 16003  10.130.2.1                GET /allsubmission.php HTTP/1.1   200   2.0
# 16004  10.130.2.1     GET /showcode.php?id=309&nm=ham05 HTTP/1.1   200   2.0
# 16005  10.130.2.1                GET /allsubmission.php HTTP/1.1   200   2.0
# 16006  10.130.2.1                         GET /home.php HTTP/1.1   200   2.0
#
#               Date Hour
# ...

# %%
df_1.isnull().sum()
# Out:
# IP       0
# URL      0
# Staus    0
# Day      0
# Date     0
# Hour     0
# dtype: int64

# %%
df_1['Minute'] = df7

df_1.head()
# Out:
# c:\users\pritam\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#            IP                                            URL Staus   Day  \
# 0  10.128.2.1                        GET /login.php HTTP/1.1   200  29.0
# 1  10.128.2.1                     POST /process.php HTTP/1.1   302  29.0
# 2  10.128.2.1                         GET /home.php HTTP/1.1   200  29.0
# 3  10.131.2.1          GET /js/vendor/moment.min.js HTTP/1.1   200  29.0
# 4  10.130.2.1  GET /bootstrap-3.3.7/js/bootstrap.js HTTP/1.1   200  29.0
#
#           Date Hour Minute
# 0  29/Nov/2017   06     58
# 1  29/Nov/2017   06     59
# ...

# %%
df_1['Second'] = df8

df_1.sample(10)
# Out:
# c:\users\pritam\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#                IP                                                URL Staus  \
# 8273   10.130.2.1                            GET /login.php HTTP/1.1   200
# 11227  10.130.2.1                            GET /login.php HTTP/1.1   200
# 8419   10.131.0.1                             GET /home.php HTTP/1.1   302
# 10169  10.130.2.1                            GET /login.php HTTP/1.1   200
# 8970   10.130.2.1                   GET /archive.php?page=2 HTTP/1.1   200
# 630    10.131.2.1  GET /bootstrap-3.3.7/js/bootstrap.min.js HTTP/1.1   200
# ...

# %%
from matplotlib import pyplot as plt
import matplotlib.pyplot as plt
from matplotlib import rcParams
from matplotlib.cm import rainbow
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')
import seaborn as sns

# %%
df_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15789 entries, 0 to 16006
# Data columns (total 8 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   IP      15789 non-null  object
#  1   URL     15789 non-null  object
#  2   Staus   15789 non-null  object
#  3   Day     15789 non-null  float64
#  4   Date    15789 non-null  object
#  5   Hour    15789 non-null  object
#  6   Minute  15789 non-null  object
#  7   Second  15789 non-null  object
# dtypes: float64(1), object(7)
# memory usage: 1.1+ MB

# %%
df_1.describe
# Out:
# <bound method NDFrame.describe of                IP                                            URL Staus   Day  \
# 0      10.128.2.1                        GET /login.php HTTP/1.1   200  29.0
# 1      10.128.2.1                     POST /process.php HTTP/1.1   302  29.0
# 2      10.128.2.1                         GET /home.php HTTP/1.1   200  29.0
# 3      10.131.2.1          GET /js/vendor/moment.min.js HTTP/1.1   200  29.0
# 4      10.130.2.1  GET /bootstrap-3.3.7/js/bootstrap.js HTTP/1.1   200  29.0
# ...           ...                                            ...   ...   ...
# 16002  10.130.2.1     GET /showcode.php?id=309&nm=ham05 HTTP/1.1   200   2.0
# 16003  10.130.2.1                GET /allsubmission.php HTTP/1.1   200   2.0
# 16004  10.130.2.1     GET /showcode.php?id=309&nm=ham05 HTTP/1.1   200   2.0
# 16005  10.130.2.1                GET /allsubmission.php HTTP/1.1   200   2.0
# 16006  10.130.2.1                         GET /home.php HTTP/1.1   200   2.0
#
# ...

# %%
sns.pairplot(df_1.drop("URL",axis=1),hue="IP",size=5)
plt.show()

# %%
sns.FacetGrid(data=df_1,hue='IP',size=6).map(sns.kdeplot,'Day').add_legend()
plt.grid()
plt.show()

# %%
sns.boxplot(x="IP", y="Day", data=df_1)

# %%
sns.FacetGrid(data=df_1,hue='IP',size=6).map(sns.kdeplot,'Minute').add_legend()
plt.grid()
plt.show()

# %%
sns.FacetGrid(data=df_1,hue='IP',size=6).map(sns.kdeplot,'Hour').add_legend()
plt.grid()
plt.show()

# %%
sns.FacetGrid(data=df_1,hue='IP',size=6).map(sns.kdeplot,'Second').add_legend()
plt.grid()
plt.show()

# %%
sns.FacetGrid(data=df_1,hue='IP',size=6).map(sns.kdeplot,'Staus').add_legend()
plt.grid()
plt.show()

# %%
sns.FacetGrid(data=df_1,hue='IP',size=6).map(plt.bar,'Day','Staus').add_legend()
plt.grid()
plt.show()

# %%
sns.FacetGrid(data=df_1,hue='Hour',size=6).map(plt.bar,'Day','Staus').add_legend()
plt.grid()
plt.show()

# %%
sns.FacetGrid(data=df_1,hue='Hour',size=6).map(plt.bar,'IP','Staus').add_legend()
plt.grid()
plt.show()

# %%
df_u=df_1.URL.str.split('/',expand=True)

df_u
# Out:
#            0                                  1       2                   3  \
# 0       GET                      login.php HTTP     1.1                None
# 1      POST                    process.php HTTP     1.1                None
# 2       GET                       home.php HTTP     1.1                None
# 3       GET                                  js  vendor  moment.min.js HTTP
# 4       GET                     bootstrap-3.3.7      js   bootstrap.js HTTP
# ...      ...                                ...     ...                 ...
# 16002   GET   showcode.php?id=309&nm=ham05 HTTP     1.1                None
# 16003   GET              allsubmission.php HTTP     1.1                None
# 16004   GET   showcode.php?id=309&nm=ham05 HTTP     1.1                None
# 16005   GET              allsubmission.php HTTP     1.1                None
# 16006   GET                       home.php HTTP     1.1                None
#
#           4
# 0      None
# 1      None
# 2      None
# ...

# %%
df_u.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15789 entries, 0 to 16006
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       15789 non-null  object
#  1   1       15789 non-null  object
#  2   2       15789 non-null  object
#  3   3       5187 non-null   object
#  4   4       2562 non-null   object
# dtypes: object(5)
# memory usage: 1.3+ MB

# %%
df_u.isnull().sum()
# Out:
# 0        0
# 1        0
# 2        0
# 3    10602
# 4    13227
# dtype: int64

# %%
data_1=df_u[1]
data_1
# Out:
# 0                           login.php HTTP
# 1                         process.php HTTP
# 2                            home.php HTTP
# 3                                       js
# 4                          bootstrap-3.3.7
#                        ...
# 16002    showcode.php?id=309&nm=ham05 HTTP
# 16003               allsubmission.php HTTP
# 16004    showcode.php?id=309&nm=ham05 HTTP
# 16005               allsubmission.php HTTP
# 16006                        home.php HTTP
# Name: 1, Length: 15789, dtype: object

# %%
data_2=df_u[0]
data_2
# Out:
# 0         GET
# 1        POST
# 2         GET
# 3         GET
# 4         GET
#          ...
# 16002     GET
# 16003     GET
# 16004     GET
# 16005     GET
# 16006     GET
# Name: 0, Length: 15789, dtype: object

# %%
df_1['Address']=data_1

# %%
df_1['Request']=data_2

# %%
df_1
# Out:
#                IP                                            URL Staus   Day  \
# 0      10.128.2.1                        GET /login.php HTTP/1.1   200  29.0
# 1      10.128.2.1                     POST /process.php HTTP/1.1   302  29.0
# 2      10.128.2.1                         GET /home.php HTTP/1.1   200  29.0
# 3      10.131.2.1          GET /js/vendor/moment.min.js HTTP/1.1   200  29.0
# 4      10.130.2.1  GET /bootstrap-3.3.7/js/bootstrap.js HTTP/1.1   200  29.0
# ...           ...                                            ...   ...   ...
# 16002  10.130.2.1     GET /showcode.php?id=309&nm=ham05 HTTP/1.1   200   2.0
# 16003  10.130.2.1                GET /allsubmission.php HTTP/1.1   200   2.0
# 16004  10.130.2.1     GET /showcode.php?id=309&nm=ham05 HTTP/1.1   200   2.0
# 16005  10.130.2.1                GET /allsubmission.php HTTP/1.1   200   2.0
# 16006  10.130.2.1                         GET /home.php HTTP/1.1   200   2.0
#
# ...

# %%
sns.FacetGrid(data=df_1,hue='Request',size=6).map(sns.kdeplot,'Day').add_legend()
plt.grid()
plt.show()

# %%
sns.FacetGrid(data=df_1,hue='Request',size=6).map(sns.kdeplot,'Hour').add_legend()
plt.grid()
plt.show()

# %%
sns.FacetGrid(data=df_1,hue='Request',size=6).map(sns.kdeplot,'Staus').add_legend()
plt.grid()
plt.show()

# %%
df_1['Address'].str.split('.').str.get(0).str.title().value_counts()
# Out:
# Login                 3426
# Home                  2653
# Js                    2091
# Css                   2001
#  Http                  862
# Bootstrap-3            573
# Contestproblem         556
# Process                317
# Archive                309
# Details                297
# Fonts                  280
# Contest                249
# Contestsubmission      228
# Robots                 224
# Img                    213
# Allsubmission          170
# Standings              167
# Profile                147
# Sign                   136
# Description            124
# Compiler                98
# Compile                 96
# Action                  83
# Pcompile                80
# Countdown               73
# Submit                  54
# Showcode                54
# Contestsubmit           53
# Logout                  44
# Favicon                 19
# Edit                    14
# Setproblem              12
# Editcontestproblem      12
# Djs                     12
# ...

# %%
ds=df_1.Address.str.split('.',expand=True)

# %%
ds.head()
# Out:
#              0         1     2     3
# 0        login  php HTTP  None  None
# 1      process  php HTTP  None  None
# 2         home  php HTTP  None  None
# 3           js      None  None  None
# 4  bootstrap-3         3     7  None

# %%
ds_1=ds[0]

# %%
ds_1
# Out:
# 0                login
# 1              process
# 2                 home
# 3                   js
# 4          bootstrap-3
#              ...
# 16002         showcode
# 16003    allsubmission
# 16004         showcode
# 16005    allsubmission
# 16006             home
# Name: 0, Length: 15789, dtype: object

# %%
df_1['Server']=ds_1
df_1
# Out:
#                IP                                            URL Staus   Day  \
# 0      10.128.2.1                        GET /login.php HTTP/1.1   200  29.0
# 1      10.128.2.1                     POST /process.php HTTP/1.1   302  29.0
# 2      10.128.2.1                         GET /home.php HTTP/1.1   200  29.0
# 3      10.131.2.1          GET /js/vendor/moment.min.js HTTP/1.1   200  29.0
# 4      10.130.2.1  GET /bootstrap-3.3.7/js/bootstrap.js HTTP/1.1   200  29.0
# ...           ...                                            ...   ...   ...
# 16002  10.130.2.1     GET /showcode.php?id=309&nm=ham05 HTTP/1.1   200   2.0
# 16003  10.130.2.1                GET /allsubmission.php HTTP/1.1   200   2.0
# 16004  10.130.2.1     GET /showcode.php?id=309&nm=ham05 HTTP/1.1   200   2.0
# 16005  10.130.2.1                GET /allsubmission.php HTTP/1.1   200   2.0
# 16006  10.130.2.1                         GET /home.php HTTP/1.1   200   2.0
#
# ...

# %%
sns.FacetGrid(data=df_1,hue='Request',size=6).map(plt.scatter,'IP','Server').add_legend()
plt.grid()
plt.show()
